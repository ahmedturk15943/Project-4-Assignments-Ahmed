# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmedturk15943/Project-4-Assignments-Ahmed/blob/main/01_intropython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# homework assignmnt

# %% [markdown]
# # intropython

# %%
# 01_add_two_numbers

def main():
    print("This program adds two numbers.")
    num1 : str = input("Enter first number: ")
    num1 : int = int(num1)
    num2  : str = input("Enter second number: ")
    num2 : int = int(num2)
    total : int = num1 + num2
    print("The total is " + str(total) + ".")


if __name__ == '__main__':
    main()

# %%
# 02_agreement_bot.md

def main():
    # Asking the user for their favorite animal
    favorite_animal = input("What's your favorite animal? ")

    # Responding with the same favorite animal
    print("My favorite animal is also " + favorite_animal + "!")

if __name__ == '__main__':
    main()

# %%
# 03_fahrenheit_to_celsius.md

def main():
    # Prompting the user to enter the temperature in Fahrenheit
    fahrenheit = float(input("Enter temperature in Fahrenheit: "))

    # Converting Fahrenheit to Celsius using the formula
    celsius = (fahrenheit - 32) * 5.0 / 9.0

    # Outputting the temperature in both Fahrenheit and Celsius
    print(f"Temperature: {fahrenheit}F = {celsius}C")

if __name__ == '__main__':
    main()

# %%
# 04_how_old_are_they.md

def main():
    anton = 21  # Anton's age is given as 21 years old
    beth = 6 + anton  # Beth is 6 years older than Anton, so add 6 to Anton's age to get Beth's
    chen = 20 + beth  # Chen is 20 years older than Beth, so add 20 to Beth's age to get Chen's
    drew = chen + anton  # Drew is as old as Chen's age plus Anton's age, so add them together
    ethan = chen  # Ethan is the same age as Chen, so set Ethan's age equal to Chen's

    # Print out all of the ages in the required format
    print(f"Anton is {anton}")
    print(f"Beth is {beth}")
    print(f"Chen is {chen}")
    print(f"Drew is {drew}")
    print(f"Ethan is {ethan}")

# This line runs the main function when the script is executed
if __name__ == '__main__':
    main()

# %%
# 05_triangle_perimeter.md

def main():
    # Get the 3 side lengths of the triangle
    side1 = float(input("What is the length of side 1? "))
    side2 = float(input("What is the length of side 2? "))
    side3 = float(input("What is the length of side 3? "))

    # Calculate the perimeter by summing the sides
    perimeter = side1 + side2 + side3

    # Print the perimeter of the triangle
    print("The perimeter of the triangle is " + str(perimeter))

if __name__ == '__main__':
    main()

# %%
# 06_square_number.md

def main():
    # Ask the user to enter a number, and cast it to float for mathematical operations
    num = float(input("Type a number to see its square: "))

    # Calculate the square of the number and print the result
    print(str(num) + " squared is " + str(num ** 2))

if __name__ == '__main__':
    main()

# %% [markdown]
# 01_expressions

# %%
# 01_dicesimulator

"""
Program: dicesimulator
----------------------
Simulate rolling two dice, three times.  Prints
the results of each die roll.  This program is used
to show how variable scope works.
"""

# Import the random library which lets us simulate random things like dice!
import random

# Number of sides on each die to roll
NUM_SIDES = 6

def roll_dice():
    """
    Simulates rolling two dice and prints their total
    """
    die1 = random.randint(1, NUM_SIDES)  # Randomly choose a number between 1 and NUM_SIDES for die1
    die2 = random.randint(1, NUM_SIDES)  # Randomly choose a number between 1 and NUM_SIDES for die2
    total = die1 + die2  # Sum the results of both dice
    print("Total of two dice:", total)  # Print the total

def main():
    # Simulate rolling the dice three times
    roll_dice()
    roll_dice()
    roll_dice()

# This provided line is required at the end of a Python file
# to call the main() function.
if __name__ == '__main__':
    main()

# %%
# 02_e=mc2

C = 299792458  # The speed of light in m/s

def main():
    # Ask the user for mass in kilograms
    mass_in_kg = float(input("Enter kilos of mass: "))

    # Calculate energy using the formula E = m * c^2
    energy_in_joules = mass_in_kg * (C ** 2)

    # Display the result
    print("e = m * C^2...")
    print("m = " + str(mass_in_kg) + " kg")
    print("C = " + str(C) + " m/s")

    # Output the energy in joules
    print(str(energy_in_joules) + " joules of energy!")

if __name__ == '__main__':
    main()

# %%
# 03_feet_to_inches

"""
An example program with constants
"""

INCHES_IN_FOOT = 12  # Conversion factor. There are 12 inches for 1 foot.

def main():
    # Get the number of feet from the user and convert it to a float
    feet = float(input("Enter number of feet: "))

    # Perform the conversion by multiplying the number of feet by 12 (INCHES_IN_FOOT)
    inches = feet * INCHES_IN_FOOT

    # Output the result in inches
    print("That is", inches, "inches!")

if __name__ == '__main__':
    main()

# %%
# 04_pythagorean_theorem

import math  # Import the math library so we can use the sqrt function

def main():
    # Get the lengths of the two perpendicular sides from the user
    ab = float(input("Enter the length of AB: "))  # Length of side AB
    ac = float(input("Enter the length of AC: "))  # Length of side AC

    # Calculate the hypotenuse (BC) using the Pythagorean theorem: BC^2 = AB^2 + AC^2
    bc = math.sqrt(ab**2 + ac**2)  # math.sqrt() computes the square root

    # Output the length of the hypotenuse
    print("The length of BC (the hypotenuse) is: " + str(bc))

if __name__ == '__main__':
    main()

# %%
# 05_remainder_division

def main():
    # Get the numbers we want to divide
    dividend = int(input("Please enter an integer to be divided: "))  # The number to be divided
    divisor = int(input("Please enter an integer to divide by: "))   # The number to divide by

    # Perform integer division and calculate the remainder
    quotient = dividend // divisor  # Integer division (quotient)
    remainder = dividend % divisor  # Remainder of the division

    # Output the result
    print(f"The result of this division is {quotient} with a remainder of {remainder}")

if __name__ == '__main__':
    main()

# %%
# 06_rolldice

import random  # Importing the random library to simulate dice rolls

# Number of sides on each die
NUM_SIDES = 6

def main():
    # Roll the dice by selecting a random number between 1 and NUM_SIDES for each die
    die1 = random.randint(1, NUM_SIDES)
    die2 = random.randint(1, NUM_SIDES)

    # Calculate the total sum of both dice rolls
    total = die1 + die2

    # Print the results of the dice rolls and the total
    print("Dice have", NUM_SIDES, "sides each.")
    print("First die:", die1)
    print("Second die:", die2)
    print("Total of two dice:", total)

# This line ensures the program runs when executed
if __name__ == '__main__':
    main()

# %%
# 06_seconds_in_year

# Useful constants to help make the math easier and cleaner!
DAYS_PER_YEAR = 365      # Number of days in a year
HOURS_PER_DAY = 24       # Number of hours in a day
MIN_PER_HOUR = 60        # Number of minutes in an hour
SEC_PER_MIN = 60         # Number of seconds in a minute

def main():
    # Calculate the number of seconds in a year using the constants
    seconds_in_year = DAYS_PER_YEAR * HOURS_PER_DAY * MIN_PER_HOUR * SEC_PER_MIN
    print("There are " + str(seconds_in_year) + " seconds in a year!")

# This line ensures the program runs when executed
if __name__ == '__main__':
    main()

# %%
# 07_tiny_mad_lib

# Sentence starter constant
SENTENCE_START: str = "Panaversity is fun. I learned to program and used Python to make my "  # adjective noun verb

def main():
    # Get the three inputs from the user to complete the sentence
    adjective: str = input("Please type an adjective and press enter. ")
    noun: str = input("Please type a noun and press enter. ")
    verb: str = input("Please type a verb and press enter. ")

    # Print the final sentence with the user-provided words
    print(SENTENCE_START + adjective + " " + noun + " " + verb + "!")

# Ensure the program runs when executed
if __name__ == '__main__':
    main()

# %% [markdown]
# 02_lists

# %%
# 01_add_many_number

def add_many_numbers(numbers) -> int:
    """
    Takes in a list of numbers and returns the sum of those numbers.
    """
    total_so_far: int = 0  # Initialize the total sum to 0
    for number in numbers:  # Iterate over the list of numbers
        total_so_far += number  # Add each number to the total sum

    return total_so_far  # Return the total sum

# This provided line is required at the end of the Python file to call the main() function
def main():
    numbers: list[int] = [1, 2, 3, 4, 5]  # Example list of numbers
    sum_of_numbers: int = add_many_numbers(numbers)  # Call the function to get the sum
    print(sum_of_numbers)  # Print the result of the sum

# Ensure that the main function is executed when the script is run
if __name__ == '__main__':
    main()

# %%
# 02_double_list

def main():
    numbers: list[int] = [1, 2, 3, 4]  # Creates a list of numbers

    for i in range(len(numbers)):  # Loop through the indices of the list
        elem_at_index = numbers[i]  # Get the element at index i in the numbers list
        numbers[i] = elem_at_index * 2  # Set the element at index i to be equal to the previous element times 2

    print(numbers)  # This should print the doubled list


# There is no need to edit code beyond this point

if __name__ == '__main__':
    main()

# %%
# 03_erase_canvas

""" This program implements an 'eraser' on a canvas.

The canvas consists of a grid of blue 'cells' which are drawn as rectangles on the screen.
We then create an eraser rectangle which, when dragged around the canvas, sets all of the rectangles
it is in contact with to white.
"""

from graphics import Canvas
import time

# Define the constants for the canvas and cell sizes
CANVAS_WIDTH : int = 400
CANVAS_HEIGHT : int = 400

CELL_SIZE : int = 40  # Size of each cell on the grid
ERASER_SIZE : int = 20  # Size of the eraser

def erase_objects(canvas, eraser):
    """Erase objects in contact with the eraser."""
    # Get mouse position to know which cells to erase
    mouse_x = canvas.get_mouse_x()
    mouse_y = canvas.get_mouse_y()

    # Calculate the eraser's boundary
    left_x = mouse_x
    top_y = mouse_y
    right_x = left_x + ERASER_SIZE
    bottom_y = top_y + ERASER_SIZE

    # Find all objects that overlap with the eraser
    overlapping_objects = canvas.find_overlapping(left_x, top_y, right_x, bottom_y)

    # Change the color of the overlapping objects (except for the eraser itself) to white
    for overlapping_object in overlapping_objects:
        if overlapping_object != eraser:
            canvas.set_color(overlapping_object, 'white')

# Main function to set up the canvas and the eraser tool
def main():
    # Create the canvas
    canvas = Canvas(CANVAS_WIDTH, CANVAS_HEIGHT)

    # Calculate the number of rows and columns for the grid
    num_rows = CANVAS_HEIGHT // CELL_SIZE
    num_cols = CANVAS_WIDTH // CELL_SIZE

    # Create the grid of blue cells
    for row in range(num_rows):
        for col in range(num_cols):
            left_x = col * CELL_SIZE
            top_y = row * CELL_SIZE
            right_x = left_x + CELL_SIZE
            bottom_y = top_y + CELL_SIZE

            # Create each blue cell
            cell = canvas.create_rectangle(left_x, top_y, right_x, bottom_y, 'blue')

    # Wait for the user to click to start creating the eraser
    canvas.wait_for_click()

    # Get the starting position of the eraser based on the last click
    last_click_x, last_click_y = canvas.get_last_click()

    # Create the eraser as a pink rectangle
    eraser = canvas.create_rectangle(
        last_click_x,
        last_click_y,
        last_click_x + ERASER_SIZE,
        last_click_y + ERASER_SIZE,
        'pink'
    )

    # Move the eraser and erase objects that it touches
    while True:
        # Get the current mouse position
        mouse_x = canvas.get_mouse_x()
        mouse_y = canvas.get_mouse_y()

        # Move the eraser to the mouse position
        canvas.moveto(eraser, mouse_x, mouse_y)

        # Erase anything that the eraser touches
        erase_objects(canvas, eraser)

        # Slow down the loop slightly to make it more responsive and prevent CPU overuse
        time.sleep(0.05)

# Run the main function if this script is executed
if __name__ == '__main__':
    main()

# %%
# 04_flowing_with_data_structures

def add_three_copies(my_list, data):
    """ Adds three copies of 'data' to the list 'my_list' """
    for i in range(3):
        my_list.append(data)  # Append data three times to the list

########## No need to edit code past this point

def main():
    # Get input from the user
    message = input("Enter a message to copy: ")

    # Initialize an empty list
    my_list = []

    # Print the list before calling the function
    print("List before:", my_list)

    # Call the function to add 3 copies of the message
    add_three_copies(my_list, message)

    # Print the list after calling the function
    print("List after:", my_list)

# Ensure the main function runs when the script is executed
if __name__ == "__main__":
    main()

# %%
# 05_get_first_element

def get_first_element(lst):
    """
    Prints the first element of a provided list.
    """
    print(lst[0])  # Print the first element of the list

def get_lst():
    """
    Prompts the user to enter one element of the list at a time and returns the resulting list.
    """
    lst = []  # Initialize an empty list
    elem: str = input("Please enter an element of the list or press enter to stop. ")
    while elem != "":  # Continue adding elements until an empty input is given
        lst.append(elem)  # Append the entered element to the list
        elem = input("Please enter an element of the list or press enter to stop. ")
    return lst  # Return the populated list

def main():
    lst = get_lst()  # Get the list of elements from the user
    get_first_element(lst)  # Print the first element of the list

# This provided line is required at the end of the file to call the main() function
if __name__ == '__main__':
    main()

# %%
# 06_get_last_element

def get_last_element(lst):
    """
    Prints the last element of the provided list.
    """
    # Use negative indexing to get the last element
    print(lst[-1])  # Efficient way to access the last element

def get_lst():
    """
    Prompts the user to enter one element of the list at a time and returns the resulting list.
    """
    lst = []  # Initialize an empty list
    elem = input("Please enter an element of the list or press enter to stop. ")
    while elem != "":  # Continue adding elements until the user presses enter without input
        lst.append(elem)  # Append the entered element to the list
        elem = input("Please enter an element of the list or press enter to stop. ")
    return lst  # Return the populated list

def main():
    lst = get_lst()  # Get the list of elements from the user
    get_last_element(lst)  # Print the last element of the list

# This provided line is required at the end of the file to call the main() function
if __name__ == '__main__':
    main()

# %%
# 07_get_list

def main():
    lst = []  # Make an empty list to store values in

    val = input("Enter a value: ")  # Get the initial value
    while val:  # Continue while the input isn't an empty string
        lst.append(val)  # Add the input value to the list
        val = input("Enter a value: ")  # Get the next value to add

    print("Here's the list:", lst)  # Print the list once the loop ends


# This provided line is required at the end of the Python file
# to call the main() function
if __name__ == '__main__':
    main()

# %%
# 08_shorten

MAX_LENGTH : int = 3  # Set the maximum allowable length for the list

def shorten(lst):
    """Removes elements from the end of the list and prints each one."""
    while len(lst) > MAX_LENGTH:  # Continue removing elements until the list length is <= MAX_LENGTH
        last_elem = lst.pop()  # Remove the last element
        print(last_elem)  # Print the removed element

def get_lst():
    """
    Prompts the user to enter one element of the list at a time and returns the resulting list.
    """
    lst = []
    elem = input("Please enter an element of the list or press enter to stop: ")
    while elem != "":
        lst.append(elem)  # Add the input to the list
        elem = input("Please enter an element of the list or press enter to stop: ")
    return lst

def main():
    lst = get_lst()  # Get the list from the user
    shorten(lst)  # Shorten the list by removing elements from the end if necessary

if __name__ == '__main__':
    main()

# %% [markdown]
# 03_if_statements

# %%
# 01_print_events

def main():
    # Looping through the first 20 numbers (from 0 to 19)
    for i in range(20):
        print(i * 2)  # Multiply the loop variable by 2 to get even numbers

# Call the main function when "run", no need to edit anything below!
if __name__ == "__main__":
    main()

# %%
# 02_international_voting_age

PETURKSBOUIPO_AGE = 16
STANLAU_AGE = 25
MAYENGUA_AGE = 48

def main():
    # Get the user's age
    user_age = int(input("How old are you? "))

    # Check if the user can vote in Peturksbouipo
    if user_age >= PETURKSBOUIPO_AGE:
        print("You can vote in Peturksbouipo where the voting age is " + str(PETURKSBOUIPO_AGE) + ".")
    else:
        print("You cannot vote in Peturksbouipo where the voting age is " + str(PETURKSBOUIPO_AGE) + ".")

    # Check if the user can vote in Stanlau
    if user_age >= STANLAU_AGE:
        print("You can vote in Stanlau where the voting age is " + str(STANLAU_AGE) + ".")
    else:
        print("You cannot vote in Stanlau where the voting age is " + str(STANLAU_AGE) + ".")

    # Check if user can vote in Mayengua
    if user_age >= MAYENGUA_AGE:
        print("You can vote in Mayengua where the voting age is " + str(MAYENGUA_AGE) + ".")
    else:
        print("You cannot vote in Mayengua where the voting age is " + str(MAYENGUA_AGE) + ".")

# Call the main function when "run", no need to edit anything below!
if __name__ == '__main__':
    main()

# %%
# 03_leap_year

def main():
    # Get the year to check from the user
    year = int(input('Please input a year: '))

    # Check if the year is a leap year based on the given criteria
    if year % 4 == 0:  # Checking if the year is divisible by 4
        if year % 100 == 0:  # Checking if the year is divisible by 100
            if year % 400 == 0:  # Checking if the year is divisible by 400
                print("That's a leap year!")
            else:  # The year is divisible by 100 but not by 400
                print("That's not a leap year.")
        else:  # The year is divisible by 4 but not by 100
            print("That's a leap year!")
    else:  # The year is not divisible by 4
        print("That's not a leap year.")


# This line ensures that the main function is called when running the program
if __name__ == '__main__':
    main()

# %%
# 04_tall_enough_to_ride

MINIMUM_HEIGHT : int = 50  # Minimum height required to ride (arbitrary units)

def main():
    # Prompt the user for their height
    height = float(input("How tall are you? "))

    # Compare the user's height with the minimum required height
    if height >= MINIMUM_HEIGHT:
        print("You're tall enough to ride!")
    else:
        print("You're not tall enough to ride, but maybe next year!")

# Optional: Extend the program to keep asking the user for their height
def tall_enough_extension():
    while True:
        height = input("How tall are you? (Press enter to quit) ")

        # Exit the loop if the user doesn't enter anything
        if height == "":
            break

        height = float(height)  # Convert the input to a float
        if height >= MINIMUM_HEIGHT:
            print("You're tall enough to ride!")
        else:
            print("You're not tall enough to ride, but maybe next year!")

# Uncomment below to test the repeated height checking
#tall_enough_extension()

if __name__ == '__main__':
    main()  # For the basic program

# %%
# 05_random_numbers

import random

N_NUMBERS : int = 10  # We want 10 random numbers
MIN_VALUE : int = 1    # The minimum value for the random numbers
MAX_VALUE : int = 100  # The maximum value for the random numbers

def main():
    # Generate and print 10 random numbers between MIN_VALUE and MAX_VALUE
    for _ in range(N_NUMBERS):
        print(random.randint(MIN_VALUE, MAX_VALUE), end=" ")  # Print numbers in a single line

if __name__ == '__main__':
    main()

# %% [markdown]
# 04_dictionaries

# %%
# 00_count_nums

def get_user_numbers():
    """
    Create an empty list.
    Ask the user to input numbers and store them in a list.
    Once they enter a blank line, break out of the loop and return the list.
    """
    user_numbers = []
    while True:
        user_input = input("Enter a number: ")

        # If the user enters a blank line, break out of the loop and stop asking for input
        if user_input == "":
            break

        # convert the user input to an integer and add it to the list
        num = int(user_input)
        user_numbers.append(num)

    return user_numbers

def count_nums(num_lst):
    """
    Create an empty dictionary.
    Loop over the list of numbers.
    If the number is not in the dictionary, add it as a key with a value of 1.
    If the number is in the dictionary, increment its value by 1.
    """
    num_dict = {}
    for num in num_lst:
        if num not in num_dict:
            num_dict[num] = 1
        else:
            num_dict[num] += 1

    return num_dict

def print_counts(num_dict):
    """
    Loop over the dictionary and print out each key and its value.
    """
    for num in num_dict:
        print(str(num) + " appears " + str(num_dict[num]) + " times.")

def main():
    """
    Ask the user to input numbers and store them in a list. Once they enter a blank line,
    print out the number of times each number appeared in the list.
    """
    user_numbers = get_user_numbers()  # Get the list of numbers from user input
    num_dict = count_nums(user_numbers)  # Get the count of each number
    print_counts(num_dict)  # Print the counts

# Python boilerplate.
if __name__ == '__main__':
    main()

# %%
# 01_phonebook

def read_phone_numbers():
    """
    Ask the user for names/numbers to store in a phonebook (dictionary).
    Returns the phonebook.
    """
    phonebook = {}  # Create an empty phonebook dictionary

    while True:
        name = input("Name: ")
        if name == "":
            break  # Break the loop if the user enters an empty name
        number = input("Number: ")
        phonebook[name] = number  # Add name and number to the dictionary

    return phonebook


def print_phonebook(phonebook):
    """
    Prints out all the names/numbers in the phonebook.
    """
    for name in phonebook:
        print(str(name) + " -> " + str(phonebook[name]))  # Print each name and their associated number


def lookup_numbers(phonebook):
    """
    Allow the user to lookup phone numbers in the phonebook
    by looking up the number associated with a name.
    """
    while True:
        name = input("Enter name to lookup: ")
        if name == "":
            break  # Exit the loop if the user enters an empty name
        if name not in phonebook:
            print(name + " is not in the phonebook")  # Print if the name is not found
        else:
            print(phonebook[name])  # Print the phone number for the name


def main():
    """
    Main function to run the phonebook program.
    It reads phone numbers, prints the phonebook, and allows name lookup.
    """
    phonebook = read_phone_numbers()  # Read names and numbers into the phonebook
    print_phonebook(phonebook)  # Print the phonebook
    lookup_numbers(phonebook)  # Allow the user to look up phone numbers


# Python boilerplate to run the main function
if __name__ == '__main__':
    main()

# %%
# 02_pop_up_shop

def main():
    # Dictionary storing fruit prices
    fruits = {'apple': 1.5, 'durian': 50, 'jackfruit': 80, 'kiwi': 1, 'rambutan': 1.5, 'mango': 5}

    total_cost = 0  # Variable to store the total cost

    # Loop through each fruit in the dictionary
    for fruit_name in fruits:
        price = fruits[fruit_name]  # Get the price of the current fruit
        amount_bought = int(input("How many (" + fruit_name + ") do you want to buy?: "))  # User input for quantity

        # Add the cost of the current fruit to the total
        total_cost += (price * amount_bought)

    # Print the total cost
    print("Your total is $" + str(total_cost))

# Python boilerplate to run the main function
if __name__ == '__main__':
    main()

# %%
# 03_powerful_passwords

from hashlib import sha256

def login(email, stored_logins, password_to_check):
    """
    Returns True if the hash of the password we are checking matches the one in stored_logins
    for a specific email. Otherwise, returns False.

    email: the email we are checking the password for
    stored_logins: a dictionary pointing from an email to its hashed password
    password_to_check: a password we want to test alongside the email to login with
    """

    # Check if the stored password hash for the email matches the hash of the input password
    if stored_logins[email] == hash_password(password_to_check):
        return True
    return False

def hash_password(password):
    """
    Takes in a password and returns the SHA256 hashed value for that specific password.

    Inputs:
        password: the password we want

    Outputs:
        the hashed form of the input password
    """
    # Return the SHA256 hash of the password
    return sha256(password.encode()).hexdigest()

def main():
    # stored_logins is a dictionary with emails as keys and hashed passwords as values
    stored_logins = {
        "example@gmail.com": "5e884898da28047151d0e56f8dc6292773603d0d6aabbdd62a11ef721d1542d8",  # hash for 'password'
        "code_in_placer@cip.org": "973607a4ae7b4cf7d96a100b0fb07e8519cc4f70441d41214a9f811577bb06cc",  # hash for 'Karel'
        "student@stanford.edu": "882c6df720fd99f5eebb1581a1cf975625cea8a160283011c0b9512bb56c95fb"  # hash for 'password123'
    }

    # Testing the login function with various inputs
    print(login("example@gmail.com", stored_logins, "word"))  # Should return False
    print(login("example@gmail.com", stored_logins, "password"))  # Should return True

    print(login("code_in_placer@cip.org", stored_logins, "Karel"))  # Should return True
    print(login("code_in_placer@cip.org", stored_logins, "karel"))  # Should return False

    print(login("student@stanford.edu", stored_logins, "password"))  # Should return False
    print(login("student@stanford.edu", stored_logins, "123!456?789"))  # Should return False

if __name__ == '__main__':
    main()

# %% [markdown]
# 05_loops_control_flow

# %%
# 00_guess_my_number

import random

def main():
    # Generate the secret number at random!
    secret_number = random.randint(1, 99)

    print("I am thinking of a number between 1 and 99...")

    # Get user's guess
    guess = int(input("Enter a guess: "))

    # True if guess is not equal to secret number
    while guess != secret_number:
        if guess < secret_number:  # If-statement is True if guess is less than secret number
            print("Your guess is too low")
        else:
            print("Your guess is too high")

        print()  # Print an empty line to tidy up the console for new guesses
        guess = int(input("Enter a new guess: "))  # Get a new guess from the user

    print("Congrats! The number was: " + str(secret_number))

if __name__ == '__main__':
    main()

# %%
# 01_fibonacci

MAX_TERM_VALUE : int = 10000

def main():
    # Starting values for the Fibonacci sequence
    curr_term = 0  # Fib(0)
    next_term = 1  # Fib(1)

    # Loop until the current term exceeds the maximum value
    while curr_term <= MAX_TERM_VALUE:
        print(curr_term, end=" ")  # Print the current term
        # Update terms to the next ones in the sequence
        term_after_next = curr_term + next_term
        curr_term = next_term
        next_term = term_after_next

# Python boilerplate to call main()
if __name__ == '__main__':
    main()

# %%
# 02_print_events

def main():
    # Loop to iterate 20 times (from 0 to 19)
    for i in range(20):
        print(i * 2, end=" ")  # Multiply 'i' by 2 to get even numbers and print them on the same line

# Call the main function when the script is run
if __name__ == '__main__':
    main()

# %%
# 03_wholesome_machine

# Define the affirmation string
AFFIRMATION : str = "I am capable of doing anything I put my mind to."

def main():
    # Prompt the user to type the affirmation
    print("Please type the following affirmation: " + AFFIRMATION)

    # Read the user's input
    user_feedback = input()

    # Continue asking the user until they type the correct affirmation
    while user_feedback != AFFIRMATION:
        # If the user types it incorrectly, tell them and ask again
        print("That was not the affirmation.")
        print("Please type the following affirmation: " + AFFIRMATION)

        # Read the user's input again
        user_feedback = input()

    # Once they get it right, acknowledge them
    print("That's right! :)")

# Run the main function if this script is executed directly
if __name__ == '__main__':
    main()

# %%
# 04_liftoff

def main():
    # Countdown from 10 to 1
    for i in range(10, 0, -1):  # Start from 10, stop before 0, step by -1
        print(i, end=" ")  # Print numbers on the same line with a space in between

    # After the countdown, print "Liftoff!"
    print("Liftoff!")

# Run the main function if this script is executed directly
if __name__ == '__main__':
    main()

# %%
# 05_double_it

def main():
    # Ask the user for the initial number
    curr_value = int(input("Enter a number: "))

    # While loop to double the value until it reaches or exceeds 100
    while curr_value < 100:
        # Double the current value
        curr_value *= 2
        # Print the current value after doubling
        print(curr_value, end=" ")

# Call the main function when "run", no need to edit anything below!
if __name__ == '__main__':
    main()

# %% [markdown]
# 06_functions

# %%
# 00_averages

def average(a: float, b: float) -> float:
    """
    Returns the number which is halfway between a and b.
    This is the average of the two numbers.
    """
    sum = a + b  # Sum the two numbers
    return sum / 2  # Return the average by dividing the sum by 2

def main():
    # Test the function with different pairs of numbers
    avg_1 = average(0, 10)
    avg_2 = average(8, 10)

    # Find the average of the previously calculated averages
    final = average(avg_1, avg_2)

    # Print the results
    print("avg_1:", avg_1)
    print("avg_2:", avg_2)
    print("final:", final)

# Call the main function when "run", no need to edit anything below!
if __name__ == '__main__':
    main()

# %%
# 01_chaotic_counting

import random

DONE_LIKELIHOOD = 0.3  # The probability that done() will return True

def chaotic_counting():
    for i in range(10):
        curr_num = i + 1  # Start counting from 1 to 10
        if done():  # Check if done() returns True
            return  # If done() returns True, exit the function
        print(curr_num)  # Print the current number

def done():
    """ Returns True with a probability of DONE_LIKELIHOOD """
    if random.random() < DONE_LIKELIHOOD:  # Randomly return True based on the likelihood
        return True
    return False

def main():
    print("I'm going to count until 10 or until I feel like stopping, whichever comes first.")
    chaotic_counting()  # Call the counting function
    print("I'm done")  # Print this once chaotic_counting finishes

if __name__ == "__main__":
    main()

# %%
# 02_count_even

def count_even(lst):
    """
    Returns number of even numbers in list.
    >>> count_even([1, 2, 3, 4])
    2
    >>> count_even([1, 3, 5, 7])
    0
    """
    count = 0  # Stores the count of even numbers in the list
    for num in lst:  # Loop through the numbers in the list
        if num % 2 == 0:  # If the current number in the list is even (divisible by 2)
            count += 1  # Add one to our count!

    print(count)  # Print out how many even numbers we counted above

def get_list_of_ints():
    """
    Reads in integers until the user presses enter and returns the resulting list.
    """
    lst = []  # Make an empty list to store integers
    user_input = input("Enter an integer or press enter to stop: ")  # Get user input for an integer
    while user_input != "":  # While the user doesn't enter nothing...
        lst.append(int(user_input))  # Cast the user input into an integer and add it to our list
        user_input = input("Enter an integer or press enter to stop: ")  # Get the next user input

    return lst

def main():
    lst = get_list_of_ints()  # Get the list of integers from the user
    count_even(lst)  # Count and print the number of even numbers in the list

# The provided line is required at the end of Python file to call the main() function.
if __name__ == '__main__':
    main()

# %%
# 04_double

def double(num: int):
    # This function takes an integer num and returns the result of multiplying it by 2.
    return num * 2

def main():
    # Prompt the user to enter a number
    num = int(input("Enter a number: "))

    # Call the double function to double the entered number
    num_times_2 = double(num)

    # Print the result
    print("Double that is", num_times_2)

# Ensure the main function is executed when the script is run
if __name__ == '__main__':
    main()

# %%
# 05_get_name

def get_name():
    # This function returns the string "Sophia"
    return "Sophia"

def main():
    # Call get_name() to retrieve the name and store it in 'name'
    name = get_name()

    # Print the greeting with the name
    print("Howdy", name, "! 🤠")

# Ensure that the main function is called when the script is executed
if __name__ == '__main__':
    main()

# %%
# 06_is_odd

def main():
    # Loop through the numbers from 10 to 19 (inclusive)
    for i in range(10, 20):
        if is_odd(i):
            print(i, "odd")
        else:
            print(i, "even")

def is_odd(value: int):
    """
    Checks to see if a value is odd. If it is, returns True.
    """
    return value % 2 != 0  # Return True if the number is odd

# This code block is to call main when the script is executed
if __name__ == '__main__':
    main()

# %%
# 07_print_divisor

def print_divisors(num: int):
    # Print the header
    print("Here are the divisors of", num)

    # Loop through the numbers from 1 to num (inclusive)
    for i in range(1, num + 1):
        if num % i == 0:  # If num is divisible by i with no remainder
            print(i)

def main():
    # Ask the user for a number
    num = int(input("Enter a number: "))

    # Call the print_divisors function with the input number
    print_divisors(num)

# This code block is required to call main when the script is executed
if __name__ == '__main__':
    main()

# %%
# 08_print_multiple

def print_multiple(message: str, repeats: int):
    # Loop to print the message the specified number of times
    for i in range(repeats):
        print(message)

def main():
    # Get the message from the user
    message = input("Please type a message: ")

    # Get the number of times to repeat the message
    repeats = int(input("Enter a number of times to repeat your message: "))

    # Call print_multiple to print the message the required number of times
    print_multiple(message, repeats)

# This is the standard way to ensure the main function is called when the script runs
if __name__ == '__main__':
    main()

# %%
# 09_sentence_generator

def make_sentence(word, part_of_speech):
    if part_of_speech == 0:
        # noun
        print("I am excited to add this " + word + " to my vast collection of them!")
    elif part_of_speech == 1:
        # verb
        print("It's so nice outside today it makes me want to " + word + "!")
    elif part_of_speech == 2:
        # adjective
        print("Looking out my window, the sky is big and " + word + "!")
    else:
        # Invalid part_of_speech
        print("Part of speech must be 0, 1, or 2! Can't make a sentence.")

def main():
    # Get user input for the word
    word = input("Please type a noun, verb, or adjective: ")

    # Ask user to specify if it's a noun, verb, or adjective
    print("Is this a noun, verb, or adjective?")
    part_of_speech = int(input("Type 0 for noun, 1 for verb, 2 for adjective: "))

    # Call the function to print the appropriate sentence
    make_sentence(word, part_of_speech)

if __name__ == '__main__':
    main()

# %%
# 10_print_ones_digit

def print_ones_digit(num):
    # Print the ones digit of the number
    print("The ones digit is", num % 10)

def main():
    # Prompt the user to input a number
    num = int(input("Enter a number: "))
    # Call the function to print the ones digit
    print_ones_digit(num)

if __name__ == '__main__':
    main()

# %% [markdown]
# 07_information_flow

# %%
# 00_choosing_returns

ADULT_AGE = 18  # U.S. age for adulthood

def is_adult(age: int):
    # If age is greater than or equal to ADULT_AGE, return True
    if age >= ADULT_AGE:
        return True
    # Otherwise, return False
    return False

def main():
    # Prompt the user for their age and convert it to an integer
    age = int(input("How old is this person?: "))
    # Print whether the person is an adult or not
    print(is_adult(age))

if __name__ == "__main__":
    main()

# %%
# 01_greetings

def greet(name):
    return "Greetings " + name + "!"  # Returns a greeting with the user's name

def main():
    name = input("What's your name? ")  # Ask the user for their name
    print(greet(name))  # Call greet() and print the result

if __name__ == '__main__':
    main()  # This runs the main function

# %%
# 02_in_range

def in_range(n, low, high):
    """
    Returns True if n is between low and high, inclusive.
    high is guaranteed to be greater than low.
    """
    if n >= low and n <= high:
        return True
    return False  # If the condition is not met, return False

def main():
    # You can test the in_range function here by calling it with different values.
    print(in_range(5, 1, 10))  # Expected: True
    print(in_range(15, 1, 10)) # Expected: False

if __name__ == '__main__':
    main()  # Calls the main function to test the in_range function

# %%
# 03_in_stock

def main():
    fruit = input("Enter a fruit: ")  # Get the fruit from the user
    stock = num_in_stock(fruit)  # Get the stock count using num_in_stock function
    if stock == 0:
        print("This fruit is not in stock.")  # If stock is 0, print this message
    else:
        print("This fruit is in stock! Here is how many:")  # If stock > 0, print the stock
        print(stock)

def num_in_stock(fruit):
    """
    This function returns the number of fruit Sophia has in stock.
    If the fruit is not in stock, it returns 0.
    """
    if fruit == 'apple':
        return 2
    elif fruit == 'durian':
        return 4
    elif fruit == 'pear':A
        return 1000
    else:
        # If the fruit is not in stock, return 0
        return 0

if __name__ == '__main__':
    main()  # Calls the main function to execute the program

# %%
# 04_multiple_returns

def get_user_data():
    # Ask for first name
    first_name = input("What is your first name?: ")

    # Ask for last name
    last_name = input("What is your last name?: ")

    # Ask for email address
    email_address = input("What is your email address?: ")

    # Return the collected data as a tuple
    return first_name, last_name, email_address

def main():
    # Call get_user_data to collect user information
    user_data = get_user_data()

    # Print the received user data as a tuple
    print("Received the following user data:", user_data)

if __name__ == "__main__":
    main()

# %%
# 05_subtract_7

def subtract_seven(num):
    # Subtract 7 from the given number and return the result
    num = num - 7
    return num

def main():
    # We start with the number 7
    num = 7

    # Call the subtract_seven function to subtract 7
    num = subtract_seven(num)

    # Print the result, which should be 0
    print("This should be zero:", num)

if __name__ == '__main__':
    main()

# %% [markdown]
# online class projects

# %% [markdown]
# 01_basics

# %%
# 00_joke_bot

# Define the constants
PROMPT: str = "What do you want? "
JOKE: str = "Here is a joke for you! Panaversity GPT - Sophia is heading out to the grocery store. A programmer tells her: get a liter of milk, and if they have eggs, get 12. Sophia returns with 13 liters of milk. The programmer asks why and Sophia replies: 'because they had eggs'"
SORRY: str = "Sorry I only tell jokes."

def main():
    # Ask the user what they want
    user_input = input(PROMPT).strip().lower()  # Get the user input, remove any extra spaces, and convert to lowercase

    if user_input == "joke":  # Check if the user input is exactly "joke" (case insensitive)
        print(JOKE)  # Print the joke
    else:
        print(SORRY)  # Print the sorry message for anything else

# Run the program
if __name__ == "__main__":
    main()

# %%
# 01_double_it

def main():
    # Ask the user to enter a number
    curr_value = int(input("Enter a number: "))

    # Keep doubling the number and printing it until it reaches or exceeds 100
    while curr_value < 100:
        curr_value = curr_value * 2
        print(curr_value)

if __name__ == '__main__':
    main()

# %%
# 02_liftoff

def main():
    # Countdown from 10 to 1
    for i in range(10, 0, -1):
        print(i, end=" ")

    # Print Liftoff after the countdown
    print("Liftoff!")

if __name__ == '__main__':
    main()

# %%
# 03_guess_my_number

import random

def main():
    # Generate the secret number at random!
    secret_number: int = random.randint(1, 99)

    print("I am thinking of a number between 1 and 99...")

    # Get user's guess
    guess = int(input("Enter a guess: "))

    # Keep asking until the guess is correct
    while guess != secret_number:
        if guess < secret_number:  # If guess is less than secret number
            print("Your guess is too low")
        else:  # If guess is more than secret number
            print("Your guess is too high")

        # Ask for a new guess
        print()  # Print an empty line to tidy up the console for new guesses
        guess = int(input("Enter a new guess: "))  # Get a new guess from the user

    # Print success message when the user guesses correctly
    print("Congrats! The number was:", secret_number)

if __name__ == '__main__':
    main()

# %%
# 04_random_numbers

import random

N_NUMBERS: int = 10
MIN_VALUE: int = 1
MAX_VALUE: int = 100

def main():
    # Loop to print 10 random numbers in the range 1 to 100
    for _ in range(N_NUMBERS):
        print(random.randint(MIN_VALUE, MAX_VALUE), end=" ")

if __name__ == '__main__':
    main()

# %% [markdown]
# 02_intermediate

# %% [markdown]
# Control Flow for Console

# %%
# handout

import random

# Constants
NUM_ROUNDS: int = 5  # Number of rounds to play

def main():
    score = 0  # Initialize score to 0
    print("Welcome to the High-Low Game!")
    print("--------------------------------")

    for round_num in range(1, NUM_ROUNDS + 1):
        print(f"Round {round_num}")

        # Generate random numbers for the user and the computer
        user_number = random.randint(1, 100)
        computer_number = random.randint(1, 100)

        print(f"Your number is {user_number}")

        # Ask the user whether their number is higher or lower than the computer's number
        guess = input("Do you think your number is higher or lower than the computer's?: ").lower()

        # Validate input
        while guess not in ["higher", "lower"]:
            guess = input("Please enter either 'higher' or 'lower': ").lower()

        # Compare the user's guess to the actual result
        if guess == "higher" and user_number > computer_number:
            print(f"You were right! The computer's number was {computer_number}")
            score += 1
        elif guess == "lower" and user_number < computer_number:
            print(f"You were right! The computer's number was {computer_number}")
            score += 1
        elif user_number == computer_number:
            print(f"Aww, that's incorrect. The computer's number was {computer_number}")
        else:
            print(f"Aww, that's incorrect. The computer's number was {computer_number}")

        # Print the score after each round
        print(f"Your score is now {score}")
        print()  # Print an empty line to separate rounds visually

    # End of game
    print("Thanks for playing!")

    # Conditional evaluation based on score
    if score == NUM_ROUNDS:
        print("Wow! You played perfectly!")
    elif score >= NUM_ROUNDS // 2:
        print("Good job, you played really well!")
    else:
        print("Better luck next time!")

if __name__ == "__main__":
    main()

# %%
# solution

import random

NUM_ROUNDS = 5

def main():
    print("Welcome to the High-Low Game!")
    print('--------------------------------')

    # Milestone 5: keep track of your score
    your_score = 0

    # Milestone 4: Play multiple rounds
    for i in range(NUM_ROUNDS):
        print("Round", i + 1)
        # Milestone 1: Generate the random numbers and print them out
        computer_num = random.randint(1, 100)
        your_num = random.randint(1, 100)
        print("Your number is", your_num)

        # Milestone 2: Get user input for their choice
        choice = input("Do you think your number is higher or lower than the computer's?: ").lower()

        # Extension 1: Make sure the player inputs a valid choice (higher or lower)
        while choice != "higher" and choice != "lower":
            choice = input("Please enter either higher or lower: ").lower()

        # Milestone 3: Map out all the ways to win the round
        higher_and_correct = choice == "higher" and your_num > computer_num
        lower_and_correct = choice == "lower" and your_num < computer_num

        if higher_and_correct or lower_and_correct:
            print("You were right! The computer's number was", computer_num)
            # Milestone 5: keep track of your score
            your_score += 1
        else:
            print("Aww, that's incorrect. The computer's number was", computer_num)

        # Milestone 5: keep track of your score
        print("Your score is now", your_score)
        print()

    # Extension 2: Conditional ending messages based on performance
    print("Your final score is", your_score)

    if your_score == NUM_ROUNDS:
        print("Wow! You played perfectly!")
    elif your_score > NUM_ROUNDS // 2:
        print("Good job, you played really well!")
    else:
        print("Better luck next time!")

if __name__ == "__main__":
    main()

# %%
# starter_code

import random

NUM_ROUNDS = 5

def main():
    print("Welcome to the High-Low Game!")
    print('--------------------------------')

    # Initialize the score variable
    your_score = 0

    # Play multiple rounds
    for i in range(NUM_ROUNDS):
        print(f"Round {i + 1}")

        # Generate random numbers for both the user and the computer
        computer_num = random.randint(1, 100)
        your_num = random.randint(1, 100)
        print(f"Your number is {your_num}")

        # Get user input for the guess (higher or lower)
        choice = input("Do you think your number is higher or lower than the computer's?: ").lower()

        # Ensure the user inputs either 'higher' or 'lower'
        while choice not in ["higher", "lower"]:
            choice = input("Please enter either 'higher' or 'lower': ").lower()

        # Check if the guess is correct
        if (choice == "higher" and your_num > computer_num) or (choice == "lower" and your_num < computer_num):
            print(f"You were right! The computer's number was {computer_num}")
            your_score += 1
        else:
            print(f"Aww, that's incorrect. The computer's number was {computer_num}")

        # Display current score
        print(f"Your score is now {your_score}")
        print()

    # Display the final score and a message based on performance
    print(f"Thanks for playing! Your final score is {your_score}")

    if your_score == NUM_ROUNDS:
        print("Wow! You played perfectly!")
    elif your_score > NUM_ROUNDS // 2:
        print("Good job, you played really well!")
    else:
        print("Better luck next time!")

if __name__ == "__main__":
    main()

# %% [markdown]
# Intro to Python

# %%
# handout

def main():
    # Prompt user to enter their weight on Earth
    earth_weight = float(input("Enter a weight on Earth: "))

    # Calculate the weight on Mars (37.8% of Earth's weight)
    mars_weight = earth_weight * 0.378

    # Print the weight on Mars, rounded to 2 decimal places
    print(f"The equivalent on Mars: {round(mars_weight, 2)}")

if __name__ == "__main__":
    main()



def main():
    # Gravity constants compared to Earth's gravity
    gravity_constants = {
        'Mercury': 0.376,
        'Venus': 0.889,
        'Mars': 0.378,
        'Jupiter': 2.360,
        'Saturn': 1.081,
        'Uranus': 0.815,
        'Neptune': 1.140
    }

    # Prompt user to enter their weight on Earth
    earth_weight = float(input("Enter a weight on Earth: "))

    # Prompt user to enter a planet name
    planet = input("Enter a planet: ")

    # Check if the planet is in the gravity constants dictionary
    if planet in gravity_constants:
        # Calculate the equivalent weight on the chosen planet
        planet_weight = earth_weight * gravity_constants[planet]
        # Print the equivalent weight on the planet, rounded to 2 decimal places
        print(f"The equivalent weight on {planet}: {round(planet_weight, 2)}")
    else:
        print("Sorry, the planet you entered is not in our list.")

if __name__ == "__main__":
    main()

# %%
# solution

# Constants for gravitational constants of planets
MERCURY_GRAVITY = 0.376
VENUS_GRAVITY = 0.889
MARS_GRAVITY = 0.378
JUPITER_GRAVITY = 2.36
SATURN_GRAVITY = 1.081
URANUS_GRAVITY = 0.815
NEPTUNE_GRAVITY = 1.14
EARTH_GRAVITY = 1.0

# Constant for Mars weight multiplier
MARS_MULTIPLE = 0.378

def mars_weight():
    """Calculate weight on Mars based on Earth weight"""
    # Get the Earthling's weight from the user
    earth_weight_str = input('Enter a weight on Earth: ')

    # Convert the input string to a float so we can perform calculations
    earth_weight = float(earth_weight_str)

    # Calculate the weight on Mars
    mars_weight = earth_weight * MARS_MULTIPLE

    # Round the result to 2 decimal places
    rounded_mars_weight = round(mars_weight, 2)

    # Print the equivalent weight on Mars
    print('The equivalent weight on Mars: ' + str(rounded_mars_weight))

def planetary_weight():
    """Calculate weight on selected planet based on Earth weight"""
    # Get the Earthling's weight on Earth
    earth_weight = float(input("Enter a weight on Earth: "))

    # Ask the user for the name of the planet
    planet = input("Enter a planet: ")

    # Determine the gravitational constant for the selected planet
    if planet == "Mercury":
        gravity_constant = MERCURY_GRAVITY
    elif planet == "Venus":
        gravity_constant = VENUS_GRAVITY
    elif planet == "Mars":
        gravity_constant = MARS_GRAVITY
    elif planet == "Jupiter":
        gravity_constant = JUPITER_GRAVITY
    elif planet == "Saturn":
        gravity_constant = SATURN_GRAVITY
    elif planet == "Uranus":
        gravity_constant = URANUS_GRAVITY
    else:
        gravity_constant = NEPTUNE_GRAVITY

    # Calculate the equivalent weight on the selected planet
    planetary_weight = earth_weight * gravity_constant

    # Round the result to 2 decimal places
    rounded_planetary_weight = round(planetary_weight, 2)

    # Print the equivalent weight on the selected planet
    print("The equivalent weight on " + planet + ": " + str(rounded_planetary_weight))

def main():
    """Main function to run both Mars and Planetary Weight Calculators"""
    print("Choose an option:")
    print("1. Mars Weight Calculator")
    print("2. Planetary Weight Calculator")
    choice = input("Enter your choice (1 or 2): ")

    if choice == '1':
        mars_weight()
    elif choice == '2':
        planetary_weight()
    else:
        print("Invalid choice. Please select either 1 or 2.")

if __name__ == "__main__":
    main()

# %%
# starter_code

# Constants for gravitational constants of planets
MERCURY_GRAVITY = 0.376
VENUS_GRAVITY = 0.889
MARS_GRAVITY = 0.378
JUPITER_GRAVITY = 2.36
SATURN_GRAVITY = 1.081
URANUS_GRAVITY = 0.815
NEPTUNE_GRAVITY = 1.14
EARTH_GRAVITY = 1.0

# Constant for Mars weight multiplier
MARS_MULTIPLE = 0.378

def mars_weight():
    """Calculate weight on Mars based on Earth weight"""
    # Get the Earthling's weight from the user
    earth_weight_str = input('Enter a weight on Earth: ')

    # Convert the input string to a float so we can perform calculations
    earth_weight = float(earth_weight_str)

    # Calculate the weight on Mars
    mars_weight = earth_weight * MARS_MULTIPLE

    # Round the result to 2 decimal places
    rounded_mars_weight = round(mars_weight, 2)

    # Print the equivalent weight on Mars
    print('The equivalent weight on Mars: ' + str(rounded_mars_weight))

def planetary_weight():
    """Calculate weight on selected planet based on Earth weight"""
    # Get the Earthling's weight on Earth
    earth_weight = float(input("Enter a weight on Earth: "))

    # Ask the user for the name of the planet
    planet = input("Enter a planet: ")

    # Determine the gravitational constant for the selected planet
    if planet == "Mercury":
        gravity_constant = MERCURY_GRAVITY
    elif planet == "Venus":
        gravity_constant = VENUS_GRAVITY
    elif planet == "Mars":
        gravity_constant = MARS_GRAVITY
    elif planet == "Jupiter":
        gravity_constant = JUPITER_GRAVITY
    elif planet == "Saturn":
        gravity_constant = SATURN_GRAVITY
    elif planet == "Uranus":
        gravity_constant = URANUS_GRAVITY
    else:
        gravity_constant = NEPTUNE_GRAVITY

    # Calculate the equivalent weight on the selected planet
    planetary_weight = earth_weight * gravity_constant

    # Round the result to 2 decimal places
    rounded_planetary_weight = round(planetary_weight, 2)

    # Print the equivalent weight on the selected planet
    print("The equivalent weight on " + planet + ": " + str(rounded_planetary_weight))

def main():
    """Main function to run both Mars and Planetary Weight Calculators"""
    print("Choose an option:")
    print("1. Mars Weight Calculator")
    print("2. Planetary Weight Calculator")
    choice = input("Enter your choice (1 or 2): ")

    if choice == '1':
        mars_weight()
    elif choice == '2':
        planetary_weight()
    else:
        print("Invalid choice. Please select either 1 or 2.")

if __name__ == "__main__":
    main()

# %% [markdown]
# Lists and Dicts

# %%
# handout

# Problem #1: List Practice
def list_practice():
    # Create a list called fruit_list with some fruits
    fruit_list = ['apple', 'banana', 'orange', 'grape', 'pineapple']

    # Print the length of the list
    print("Length of the list:", len(fruit_list))

    # Add 'mango' at the end of the list
    fruit_list.append('mango')

    # Print the updated list
    print("Updated fruit list:", fruit_list)

# Problem #2: Index Game
def access_element(my_list, index):
    """Access the element at the given index."""
    if index < 0 or index >= len(my_list):
        return "Index out of range."
    return my_list[index]

def modify_element(my_list, index, new_value):
    """Modify the element at the given index with a new value."""
    if index < 0 or index >= len(my_list):
        return "Index out of range."
    my_list[index] = new_value
    return my_list

def slice_list(my_list, start, end):
    """Return a slice of the list from start to end index."""
    if start < 0 or end > len(my_list):
        return "Index out of range."
    return my_list[start:end]

def index_game():
    # Initialize a list with mixed elements
    my_list = [10, 'apple', 42, 'banana', 3.14]

    while True:
        print("\nChoose an operation:")
        print("1. Access an element")
        print("2. Modify an element")
        print("3. Slice the list")
        print("4. Exit")

        # Get user input
        choice = input("Enter your choice (1/2/3/4): ")

        if choice == '1':
            # Access an element
            index = int(input("Enter the index to access: "))
            result = access_element(my_list, index)
            print("Access result:", result)

        elif choice == '2':
            # Modify an element
            index = int(input("Enter the index to modify: "))
            new_value = input("Enter the new value: ")
            result = modify_element(my_list, index, new_value)
            print("Modified list:", result)

        elif choice == '3':
            # Slice the list
            start = int(input("Enter the start index: "))
            end = int(input("Enter the end index: "))
            result = slice_list(my_list, start, end)
            print("Sliced list:", result)

        elif choice == '4':
            # Exit the game
            print("Exiting the game.")
            break
        else:
            print("Invalid choice. Please enter 1, 2, 3, or 4.")

def main():
    print("List Practice Exercise:")
    list_practice()  # Call the list practice function

    print("\nIndex Game Exercise:")
    index_game()  # Call the index game function

if __name__ == "__main__":
    main()

# %%
# solution

# Problem #1: List Practice
def list_practice():
    # Create a list called fruit_list with the given fruits
    fruit_lst = ['apple', 'banana', 'orange', 'grape', 'pineapple']

    # Print the length of the list
    lst_length = len(fruit_lst)
    print("Length of the list:", lst_length)

    # Add 'mango' at the end of the list
    fruit_lst.append('mango')

    # Print the updated list
    print("Updated fruit list:")
    for fruit in fruit_lst:
        print(fruit)

# Problem #2: Index Game
def access_element(lst, index):
    try:
        return lst[index]
    except IndexError:
        return "Index out of range."

def modify_element(lst, index, new_value):
    try:
        lst[index] = new_value
        return lst
    except IndexError:
        return "Index out of range."

def slice_list(lst, start, end):
    try:
        return lst[start:end]
    except IndexError:
        return "Invalid indices."

def index_game():
    lst = [1, 2, 3, 4, 5]  # Example list
    print("Current list:", lst)
    print("Choose an operation: access, modify, slice")

    operation = input("Enter operation: ")

    # Handling the operations based on user input
    if operation == "access":
        index = int(input("Enter index to access: "))
        print(access_element(lst, index))
    elif operation == "modify":
        index = int(input("Enter index to modify: "))
        new_value = input("Enter new value: ")
        print(modify_element(lst, index, new_value))
    elif operation == "slice":
        start = int(input("Enter start index: "))
        end = int(input("Enter end index: "))
        print(slice_list(lst, start, end))
    else:
        print("Invalid operation.")

# Main function to execute both problems
def main():
    print("List Practice:")
    list_practice()

    print("\nIndex Game:")
    index_game()

# Call the main function to run the program
if __name__ == "__main__":
    main()
